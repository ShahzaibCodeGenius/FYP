# %%
#  Imports
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#  Configurations
img_size = (224, 224)
batch_size = 8
input_shape = img_size + (3,)
train_dir = r'D:\FYP\dataset_split\train'
val_dir = r'D:\FYP\dataset_split\val'
test_dir = r'D:\FYP\dataset_split\test'

# %%
# ==============================
# Data Generators
# ==============================

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Training data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation and Test: only rescaling
val_test_datagen = ImageDataGenerator(
    rescale=1./255
)

# ==============================
# Train Generator
# ==============================

train_ds = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

# ==============================
# Validation Generator
# ==============================

val_ds = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ==============================
# Test Generator
# ==============================

test_ds = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# ==============================
# Display Dataset Information
# ==============================

print("\n========== DATASET INFORMATION ==========")

print("Train images      :", train_ds.samples)
print("Validation images :", val_ds.samples)
print("Test images       :", test_ds.samples)

print("\nClass indices:")
print(train_ds.class_indices)

num_classes = train_ds.num_classes

print("\nNumber of classes :", num_classes)
# Out:
# Found 10500 images belonging to 3 classes.
# Found 3000 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.
#
# ========== DATASET INFORMATION ==========
# Train images      : 10500
# Validation images : 3000
# Test images       : 1500
#
# Class indices:
# {'aca': 0, 'normal': 1, 'scc': 2}
#
# Number of classes : 3

# %%
#  Load Pretrained Model (InceptionV3)
base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=input_shape)
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 750s 9us/step

# %%
#  Compile Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
#model.summary()

# %%
#  Training
early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)

history = model.fit(
    train_ds,
    epochs=20,
    validation_data=val_ds,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# c:\Users\Shahzaib Rashid\miniconda3\envs\tf_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 378s 283ms/step - accuracy: 0.8188 - loss: 0.4070 - val_accuracy: 0.9413 - val_loss: 0.1669 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 379s 288ms/step - accuracy: 0.9218 - loss: 0.1996 - val_accuracy: 0.9510 - val_loss: 0.1427 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 379s 289ms/step - accuracy: 0.9290 - loss: 0.1770 - val_accuracy: 0.9520 - val_loss: 0.1337 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 372s 283ms/step - accuracy: 0.9377 - loss: 0.1597 - val_accuracy: 0.9470 - val_loss: 0.1367 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9372 - loss: 0.1555 - val_accuracy: 0.9457 - val_loss: 0.1332 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 377s 287ms/step - accuracy: 0.9465 - loss: 0.1388 - val_accuracy: 0.9583 - val_loss: 0.1098 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 373s 284ms/step - accuracy: 0.9412 - loss: 0.1364 - val_accuracy: 0.9633 - val_loss: 0.1046 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 378s 288ms/step - accuracy: 0.9459 - loss: 0.1356 - val_accuracy: 0.9650 - val_loss: 0.0947 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 474s 361ms/step - accuracy: 0.9491 - loss: 0.1257 - val_accuracy: 0.9633 - val_loss: 0.0981 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 399s 304ms/step - accuracy: 0.9503 - loss: 0.1292 - val_accuracy: 0.9670 - val_loss: 0.0900 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 395s 301ms/step - accuracy: 0.9547 - loss: 0.1083 - val_accuracy: 0.9690 - val_loss: 0.0882 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 397s 302ms/step - accuracy: 0.9550 - loss: 0.1133 - val_accuracy: 0.9657 - val_loss: 0.0890 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 398s 303ms/step - accuracy: 0.9592 - loss: 0.1017 - val_accuracy: 0.9710 - val_loss: 0.0810 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 397s 303ms/step - accuracy: 0.9568 - loss: 0.1084 - val_accuracy: 0.9707 - val_loss: 0.0736 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 397s 303ms/step - accuracy: 0.9602 - loss: 0.1009 - val_accuracy: 0.9720 - val_loss: 0.0719 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 394s 300ms/step - accuracy: 0.9635 - loss: 0.0948 - val_accuracy: 0.9730 - val_loss: 0.0716 - learning_rate: 1.0000e-04
# Epoch 17/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 392s 299ms/step - accuracy: 0.9626 - loss: 0.0943 - val_accuracy: 0.9723 - val_loss: 0.0736 - learning_rate: 1.0000e-04
# Epoch 18/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 389s 296ms/step - accuracy: 0.9622 - loss: 0.0946 - val_accuracy: 0.9663 - val_loss: 0.0826 - learning_rate: 1.0000e-04
# Epoch 19/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 375s 285ms/step - accuracy: 0.9631 - loss: 0.0926 - val_accuracy: 0.9713 - val_loss: 0.0702 - learning_rate: 5.0000e-05
# Epoch 20/20
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 387s 295ms/step - accuracy: 0.9666 - loss: 0.0832 - val_accuracy: 0.9723 - val_loss: 0.0753 - learning_rate: 5.0000e-05

# %%
#  Evaluation
evaluation = model.evaluate(test_ds)
print("Evaluation results:", evaluation)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 44s 232ms/step - accuracy: 0.9369 - loss: 0.1423
# Evaluation results: [0.08121786266565323, 0.9653333425521851]

# %%
# Plot Accuracy & Loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#  Evaluation: Confusion Matrix & All Metrics
test_ds.reset()
pred_probs = model.predict(test_ds, steps=len(test_ds), verbose=1)
y_pred = np.argmax(pred_probs, axis=1)

# True labels
y_true = []
for i in range(len(test_ds)):
    _, labels = test_ds[i]
    y_true.extend(np.argmax(labels, axis=1))
y_true = np.array(y_true)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
class_names = list(test_ds.class_indices.keys())

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 40s 203ms/step

# %%
# Metrics: Accuracy, Precision, Recall, F1
acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# Accuracy:  0.9653
# Precision: 0.9664
# Recall:    0.9653
# F1-Score:  0.9652

# %%
#  Detailed Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          aca       0.98      0.92      0.95       500
#       normal       1.00      1.00      1.00       500
#          scc       0.92      0.98      0.95       500
#
#     accuracy                           0.97      1500
#    macro avg       0.97      0.97      0.97      1500
# weighted avg       0.97      0.97      0.97      1500

# %%
model.save('InceptionV3.keras')
